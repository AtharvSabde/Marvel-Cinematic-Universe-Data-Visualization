# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         MARVEL CINEMATIC UNIVERSE
#     </h3>
#     </div>

# %% [markdown]
# ![Marvel Movies](https://i.pinimg.com/originals/b9/3b/e5/b93be5ac37b719d59a7b40731a5c2547.gif)

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         Table of Content
#     </h3>
#     </div>

# %% [markdown]
# * **Importing Libraries and Loading Data**
#
# * **Data Information and Data Cleaning**
#
# * **Exploratory Data Analysis**
#
# * **Conclusions**

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         Importing Libraries and Loading Data
#     </h3>
#     </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objects as go
import plotly.offline as pyo
import plotly.graph_objs as go
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/mcu-movies-dataset/box_office.csv')

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:BLACK;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:CYAN;
#               text-align:center;'>
#         DATA INFORMATION AND DATA CLEANING
#     </h3>
#     </div>

# %%
df
# Out:
#           Phase                                         Film  Year_Release  \
# 0     Phase One                                     Iron Man          2008
# 1     Phase One                          The Incredible Hulk          2008
# 2     Phase One                                   Iron Man 2          2010
# 3     Phase One                                         Thor          2011
# 4     Phase One           Captain America: The First Avenger          2011
# 5     Phase One                        Marvel's The Avengers          2012
# 6     Phase Two                                   Iron Man 3          2013
# 7     Phase Two                         Thor: The Dark World          2013
# 8     Phase Two          Captain America: The Winter Soldier          2014
# 9     Phase Two                      Guardians of the Galaxy          2014
# 10    Phase Two                      Avengers: Age of Ultron          2015
# ...

# %%
df.shape
# Out:
# (32, 15)

# %%
df.columns
# Out:
# Index(['Phase', 'Film', 'Year_Release', 'U.S. release date',
#        'Box office gross U.S. and Canada',
#        'Box office gross Other territories', 'Box office gross Worldwide',
#        'All-time ranking U.S. and Canada', 'All-time ranking Worldwide',
#        'Rotten Tomatoes Rating', 'CinemaScore', 'Budget', 'Director',
#        'Producer', 'movie_image'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Phase                               32 non-null     object
#  1   Film                                32 non-null     object
#  2   Year_Release                        32 non-null     int64
#  3   U.S. release date                   32 non-null     object
#  4   Box office gross U.S. and Canada    32 non-null     int64
#  5   Box office gross Other territories  32 non-null     int64
#  6   Box office gross Worldwide          32 non-null     int64
#  7   All-time ranking U.S. and Canada    32 non-null     int64
#  8   All-time ranking Worldwide          32 non-null     int64
#  9   Rotten Tomatoes Rating              32 non-null     int64
#  10  CinemaScore                         32 non-null     object
# ...

# %%
df.describe()
# Out:
#        Year_Release  Box office gross U.S. and Canada  \
# count     32.000000                      3.200000e+01
# mean    2016.687500                      3.644254e+08
# std        4.365831                      1.893580e+08
# min     2008.000000                      1.348069e+08
# 25%     2013.750000                      2.161039e+08
# 50%     2017.000000                      3.263764e+08
# 75%     2021.000000                      4.152062e+08
# max     2023.000000                      8.583730e+08
#
#        Box office gross Other territories  Box office gross Worldwide  \
# count                        3.200000e+01                3.200000e+01
# mean                         5.572327e+08                9.216580e+08
# std                          3.796090e+08                5.526540e+08
# min                          1.299641e+08                2.647710e+08
# 25%                          3.006990e+08                5.691752e+08
# ...

# %%
df.isnull().sum()
# Out:
# Phase                                 0
# Film                                  0
# Year_Release                          0
# U.S. release date                     0
# Box office gross U.S. and Canada      0
# Box office gross Other territories    0
# Box office gross Worldwide            0
# All-time ranking U.S. and Canada      0
# All-time ranking Worldwide            0
# Rotten Tomatoes Rating                0
# CinemaScore                           0
# Budget                                0
# Director                              0
# Producer                              0
# movie_image                           0
# dtype: int64

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:cyan;
#               text-align:center;'>
#          EXPLORATORY DATA ANALYSIS
#     </h3>
#     </div>

# %% [markdown]
# ## Movies Per Year

# %%
film_year = df.Year_Release.value_counts().rename_axis('Year_Release').reset_index(name='Film') 
plt.figure(figsize=(14,8))
plt.title("No. of Films released each year")
c1 = sns.barplot(x="Year_Release",y="Film",data=film_year,palette="flare")
c1.bar_label(c1.containers[0])
plt.show()

# %% [markdown]
# ## Box office gross Worldwide

# %%
box_ofc_p1 = df.query("Phase=='Phase One'")
box_ofc_p2 = df.query("Phase=='Phase Two'")
box_ofc_p3 = df.query("Phase=='Phase Three'")
box_ofc_p4 = df.query("Phase=='Phase Four'")
box_ofc_p5 = df.query("Phase=='Phase Five'")

trace1 = go.Bar(
    x=box_ofc_p1['Film'],      
    y=box_ofc_p1['Box office gross Worldwide'],
    name = 'Phase 1',
    marker=dict(color='#FFD700')
)
trace2 = go.Bar(
    x=box_ofc_p2['Film'],      
    y=box_ofc_p2['Box office gross Worldwide'],
    name = 'Phase 2',
    marker=dict(color='#9EA0A1')
)
trace3 = go.Bar(
    x=box_ofc_p3['Film'],      
    y=box_ofc_p3['Box office gross Worldwide'],
    name = 'Phase 3',
    marker=dict(color='#CD7F32')
)
trace4 = go.Bar(
    x=box_ofc_p4['Film'],      
    y=box_ofc_p4['Box office gross Worldwide'],
    name = 'Phase 4',
    marker=dict(color='#0b7314')
)
trace5 = go.Bar(
     x=box_ofc_p5['Film'],
     y=box_ofc_p5['Box office gross Worldwide'],
     name = 'Phase 5',
     marker = dict(color = '#f01707')
)
data = [trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
    title='Worldwide Box Office by Phases'
)
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ## Films And Their Budget

# %%
budget_rate = df.groupby('Film').mean().sort_values('Budget', ascending = False).index

plt.figure(figsize=(20,12))
ax = sns.barplot(y = "Film", x = "Budget" , data = df, order = budget_rate)
ax.bar_label(ax.containers[0])
plt.title(" Film with Highest Budget" , size = 20)
plt.show()
plt.clf()

# %% [markdown]
# ## All-time ranking Worldwide

# %%
rating = df.groupby('Film').mean().sort_values('All-time ranking Worldwide', ascending = True).index

plt.figure(figsize=(20,12))
ax = sns.barplot(y = "Film", x = "All-time ranking Worldwide" , data = df, order = rating)
ax.bar_label(ax.containers[0])
plt.title("All-time ranking Worldwide" , size = 20)
plt.show()
plt.clf()

# %% [markdown]
# ## Rotten Tomatoes Rating

# %%
order_rate = df.groupby('Film').mean().sort_values('Rotten Tomatoes Rating', ascending = False).index

plt.figure(figsize=(20,12))
ax = sns.barplot(y = "Film", x = "Rotten Tomatoes Rating" , data = df, order = order_rate)
ax.bar_label(ax.containers[0])
plt.title(" Film with Highest Rotten Tomatoes Rating" , size = 20)
plt.show()
plt.clf()

# %% [markdown]
# ## Box office gross Worldwide   V/S    Rotten Tomatoes Rating

# %%
px.scatter(df,x='Rotten Tomatoes Rating',y='Box office gross Worldwide',color='Rotten Tomatoes Rating',color_continuous_scale=px.colors.sequential.Plasma,template='plotly_dark',title='<b>Box office gross Worldwide Versus Rotten Tomatoes Rating')
# Out:
# <div>                            <div id="8de7d5be-e3a8-4c6a-88a8-38b9b588bfa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8de7d5be-e3a8-4c6a-88a8-38b9b588bfa5")) {                    Plotly.newPlot(                        "8de7d5be-e3a8-4c6a-88a8-38b9b588bfa5",                        [{"hovertemplate":"Rotten Tomatoes Rating=%{marker.color}<br>Box office gross Worldwide=%{y}<extra></extra>","legendgroup":"","marker":{"color":[94,67,71,77,79,91,79,66,90,92,76,83,90,89,85,92,93,96,85,87,79,94,90,79,91,47,93,74,64,84,47,82],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[94,67,71,77,79,91,79,66,90,92,76,83,90,89,85,92,93,96,85,87,79,94,90,79,91,47,93,74,64,84,47,82],"xaxis":"x","y":[
# ...

# %% [markdown]
# ## All-time ranking Worldwide V/S Rotten Tomatoes Rating

# %%
px.scatter(df,x='Rotten Tomatoes Rating',y='All-time ranking Worldwide',color='Rotten Tomatoes Rating',color_continuous_scale=px.colors.sequential.Plasma,template='plotly_dark',title='<b> All-time ranking Worldwide Versus Rotten Tomatoes Rating')
# Out:
# <div>                            <div id="9329c885-3587-495f-9664-676c4f610eb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9329c885-3587-495f-9664-676c4f610eb0")) {                    Plotly.newPlot(                        "9329c885-3587-495f-9664-676c4f610eb0",                        [{"hovertemplate":"Rotten Tomatoes Rating=%{marker.color}<br>All-time ranking Worldwide=%{y}<extra></extra>","legendgroup":"","marker":{"color":[94,67,71,77,79,91,79,66,90,92,76,83,90,89,85,92,93,96,85,87,79,94,90,79,91,47,93,74,64,84,47,82],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[94,67,71,77,79,91,79,66,90,92,76,83,90,89,85,92,93,96,85,87,79,94,90,79,91,47,93,74,64,84,47,82],"xaxis":"x","y":[
# ...

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:black;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:cyan;
#               text-align:center;'>
#          Conclusions
#     </h3>
#     </div>

# %% [markdown]
# * #### Total of 32 movies have been released so far (5-May-2023)
#
#
# *  Movie With Highest Budget = `Avengers: Age of Ultron` with Budget of $444000000
#
#
# *   Movie With Highest Box office gross Worldwide = `Avengers: Endgame`  with Total Gross of $2797800564
#
#
# *  `Avengers: Endgame` holds the best 'All-time ranking Worldwide' for MCU .
#
#
# *  MCU Movie with Highest Rotten Tomatoes Rating = `Black Panther` with 96%
#
#
# *  There Is No Correlation Between Box office gross Worldwide and Rotten Tomatoes Rating
#
#
# *  There Is Correlation Between All-time ranking Worldwide and Rotten Tomatoes Rating
